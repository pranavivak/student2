# %% [markdown]
# ---
# toc: true
# comments: false
# layout: post
# title: Textbased Hangman game
# type: hacks
# courses: { compsci: {week: 3 } }
# ---

# %%
import random

def choose_word():
    word_list = ["python", "hangman", "programming", "computer", "game", "developer"]
    return random.choice(word_list)

def display_word(word, guessed_letters):
    display = ""
    for letter in word:
        if letter in guessed_letters:
            display += letter
        else:
            display += "_"
    return display

def hangman():
    word_to_guess = choose_word()
    guessed_letters = []
    attempts_left = 6

    print("Welcome to Hangman!")
    
    while True:
        print("\nWord:", display_word(word_to_guess, guessed_letters))
        print("Guessed letters:", ", ".join(guessed_letters))
        print(f"Attempts left: {attempts_left}")

        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please enter a single letter.")
            continue

        if guess in guessed_letters:
            print("You've already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess not in word_to_guess:
            attempts_left -= 1
            print("Incorrect guess!")
            if attempts_left == 0:
                print("You've run out of attempts. The word was:", word_to_guess)
                break

        if set(word_to_guess).issubset(guessed_letters):
            print("Congratulations! You've guessed the word:", word_to_guess)
            break

    play_again = input("Do you want to play again? (yes/no): ").lower()
    if play_again == "yes":
        hangman()

if __name__ == "__main__":
    hangman()
# Out:
# Welcome to Hangman!
#
# Word: ___________
# Guessed letters:
# Attempts left: 6
#
# Word: _____a_____
# Guessed letters: a
# Attempts left: 6
# Incorrect guess!
#
# Word: _____a_____
# Guessed letters: a, e
# Attempts left: 5
#
# Word: _____a__i__
# Guessed letters: a, e, i
# Attempts left: 5
# Incorrect guess!
#
# Word: _____a__i__
# Guessed letters: a, e, i, d
# Attempts left: 4
# Incorrect guess!
#
# Word: _____a__i__
# Guessed letters: a, e, i, d, k
# Attempts left: 3
# You've already guessed that letter.
#
# Word: _____a__i__
# Guessed letters: a, e, i, d, k
# Attempts left: 3
# You've already guessed that letter.
#
# Word: _____a__i__
# Guessed letters: a, e, i, d, k
# Attempts left: 3
# You've already guessed that letter.
#
# Word: _____a__i__
# Guessed letters: a, e, i, d, k
# Attempts left: 3
# Incorrect guess!
#
# Word: _____a__i__
# Guessed letters: a, e, i, d, k, z
# Attempts left: 2
# You've already guessed that letter.
#
# Word: _____a__i__
# Guessed letters: a, e, i, d, k, z
# Attempts left: 2
#
# Word: _____ammi__
# Guessed letters: a, e, i, d, k, z, m
# Attempts left: 2
# You've already guessed that letter.
#
# Word: _____ammi__
# Guessed letters: a, e, i, d, k, z, m
# Attempts left: 2
#
# Word: p____ammi__
# Guessed letters: a, e, i, d, k, z, m, p
# Attempts left: 2
#
# Word: pr__rammi__
# Guessed letters: a, e, i, d, k, z, m, p, r
# Attempts left: 2
#
# Word: pro_rammi__
# Guessed letters: a, e, i, d, k, z, m, p, r, o
# Attempts left: 2
#
# Word: programmi_g
# Guessed letters: a, e, i, d, k, z, m, p, r, o, g
# Attempts left: 2
# Congratulations! You've guessed the word: programming
